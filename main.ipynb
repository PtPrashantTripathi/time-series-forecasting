# %%
from data import *
# list = []
# for val in data:
#     list.append(val.split('</td><td>'))
with open(r'/home/pandit/Desktop/model/new.csv', 'w') as fp:
    for item in data:
        fp.write("%s\n" % item.split('</td><td>'))
    print('Done')
# Out:
# Done

# %%
from data import *
for index,item in enumerate(data):
    if(item.count!=6):
        print(index,item[0])
# Out:
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# <
# ...
